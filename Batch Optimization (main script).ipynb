# %%
import numpy as np
import pandas as pd
import time
import folium

from batch_classes import LocationType, Location, Dropoff, Pickup, Order

from preprocessor import preprocess_excel_to_objects, get_distance_matrix, parse_distance_matrix
from batch_manager import BatchManager

pd.set_option('display.max_rows', None)  # row limit off

# %%
# Google API - Distance Matrix API
YOUR_API_KEY = ""

# %%
def batch_optimization(
    sheet_name=None, 
    order_num=20, 
    max_capacity=None, 
    max_distance=None, 
    delay_minute_per_task=None, 
    first_order_pickup_duration=None
):
    
    start_time = time.time()
    
    orders, locations = preprocess_excel_to_objects(
        file_path='../../../repository/route_model/raw_data/Data-for-Batch-Optimization.xlsx', 
        sheet_name=sheet_name,
        order_num=order_num,        
    )

    # API_KEY required while getting distance&duration matrix by Google API (Distance Matrix API)
    matrix, response_list = get_distance_matrix(sheet_name, locations, YOUR_API_KEY)
    if isinstance(matrix, tuple):
        matrix = matrix[0]
    
    bm = BatchManager(
        sheet_name, orders, locations, matrix, 
        max_capacity=max_capacity,
        max_distance=max_distance,
        delay_minute_per_task=delay_minute_per_task,
        first_order_pickup_duration=first_order_pickup_duration,
    )
    
    while len(bm.order_pool) > 0:
        # Single batch process
        
        # 2. sort by urgency of time windows
        location_list = [[order.pickup, order.dropoff] for order in bm.order_pool]
        bm.location_pool = [location for sublist in location_list for location in sublist]
        bm.location_pool.sort()
        
        # 3. select most urgent location(pickup/dropoff)
        most_urgent_location = bm.find_most_urgent_location()
        target_order = next(
            order for order in orders
            if order.order_id == most_urgent_location.order_id
        )
        bm.add_order_to_batch(target_order)
    
        bm.batch_locations = bm.gather_locations_from_order(target_order)
        bm.optimize_route()
    
        while True:
            # 4. 그 주문으로부터 평균 거리가 가까운 애들을 순차적으로 하나씩 고름
            target_order = bm.find_close_order()
            
            # 4-1.후보 주문이 없을 경우 루프 종료
            if target_order is None:
                break

            bm.current_total_distance = bm.calculate_total_distance()
            
            # 5. 주문 경로 가능한지 확인하고 거리 최소화하기 (RouteOptimizer)
            bm.batch_locations = bm.gather_locations_from_order(target_order)
            succeed = bm.optimize_route()

            # 6. 성공 시 추가
            if succeed and bm.calculate_avg_distance_with_batch_orders(target_order) < bm.distance_threshold:
                bm.add_order_to_batch(target_order)
                bm.reset_failed_pool()
            
            # 7. 넘으면 추가 X
            else:
                bm.delete_location_from_order(target_order)
                bm.add_to_failed_pool(target_order)
                bm.update_arrival_time()
    
        # 8. 배치 마무리 (배치 객체 생성, order_pool과 locations에서 값 제거)
        bm.add_current_batch_to_list()
        bm.delete_batch_from_pool()
        bm.reset_failed_pool()
    
    print(f"Number of batch: {len(bm.batch_list)}")
    print(f"Time spent: {time.time()-start_time:.2f} s")

    return bm

# %%
bm_1 = batch_optimization(
    sheet_name="SameDay Orders(8 Hours SLA)", 
    order_num=20, 
    max_capacity=30, 
    max_distance=120,
    delay_minute_per_task=5,
    first_order_pickup_duration=10,
)
# Out:
# Number of batch: 7
# Time spent: 0.39 s

# %%
bm_2 = batch_optimization(
    sheet_name="Instant Orders(1-4 Hours SLA)", 
    order_num=20, 
    max_capacity=30, 
    max_distance=120,
    delay_minute_per_task=5,
    first_order_pickup_duration=10,
)
# Out:
# Number of batch: 11
# Time spent: 0.11 s

# %%
bm_3 = batch_optimization(
    sheet_name="Mixed Orders(SameDay+Instant)", 
    order_num=20, 
    max_capacity=30, 
    max_distance=120,
    delay_minute_per_task=5,
    first_order_pickup_duration=10,
)
# Out:
# Number of batch: 9
# Time spent: 0.17 s

# %% [markdown]
# # Map

# %% [markdown]
# ## Map - show all routes

# %%
# all route
bm_1.add_all_route_to_map(number_version=False)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_619ab44eb4cb7479497c7c0ff266d90f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_619ab44eb4cb7479497c7c0ff266d90f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_619ab44eb4cb7479497c7c0ff266d90f = L.map(
#                 &quot;map_619ab44eb4cb7479497c7c0ff266d90f&quot;,
#                 {
#                     center: [-6.214, 106.8235],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d85a0ec22f3739354d753bf65bfdcff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0d85a0ec22f3739354d753bf65bfdcff.addTo(map_619ab44eb4cb7479497c7c0ff266d90f);
#
#
#             var poly_line_9c16b65aa1b118281dca9826369d2140 = L.polyline(
#                 [[-6.214, 106.8235], [-6.2133, 106.825], [-6.225, 106.8305], [-6.2145, 106.834], [-6.212, 106.799], [-6.2195, 106.8255], [-6.2235, 106.811], [-6.2275, 106.803], [-6.2305, 106.8015], [-6.2333, 106.7999], [-6.2325, 106.7995], [-6.2215, 106.8215], [-6.22, 106.8165], [-6.228, 106.81], [-6.214, 106.8305], [-6.2185, 106.8345], [-6.2185, 106.8365], [-6.224, 106.835], [-6.2295, 106.8165], [-6.2215, 106.8095], [-6.213, 106.838], [-6.2265, 106.845], [-6.2405, 106.815], [-6.2305, 106.8085], [-6.2305, 106.812], [-6.222, 106.8155]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_619ab44eb4cb7479497c7c0ff266d90f);
#
#
#             poly_line_9c16b65aa1b118281dca9826369d2140.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_056760f3bc05ee301844bde0c69e4518 = L.circleMarker(
#                 [-6.214, 106.8235],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_619ab44eb4cb7479497c7c0ff266d90f);
#
#
#             circle_marker_056760f3bc05ee301844bde0c69e4518.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 1&lt;br&gt;&lt;br&gt;Sequence number: 1&lt;br&gt;Order ID: 23&lt;br&gt;Location type: PICKUP&lt;br&gt;Weight: 8.12 kg&lt;br&gt;&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Pickup time:&lt;/span&gt;08:30:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Arrival time:&lt;/span&gt;08:40:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Delivery deadline:&lt;/span&gt;16:30:00&lt;br&gt;&lt;br&gt;Accumulated Distance: 0.00 km&lt;br&gt;Accumulated Weight: 8.12 kg&lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_dbaf560233c994b674ff92f76fa809b5 = L.circleMarker(
#                 [-6.2133, 106.825],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 7, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_619ab44eb4cb7479497c7c0ff266d90f);
#
#
#             circle_marker_dbaf560233c994b674ff92f76fa809b5.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 1&lt;br&gt;&lt;br&gt;Sequence number: 2&lt;br&gt;Order ID: 4&lt;br&gt;Location type: PICKUP&lt;br&gt;Weight: 8.7 kg&lt;br&gt;&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Pickup time:&lt;/span&gt;08:35:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Arrival time:&lt;/span&gt;08:48:01&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Delivery deadline:&lt;/span&gt;16:35:00&lt;br&gt;&

# %% [markdown]
# ## Map - 8 Hours

# %%
bm_1.add_single_route_to_map(batch_id=1, number_version=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6605e42a94b5dd358f33c70ddeb3417f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6605e42a94b5dd358f33c70ddeb3417f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6605e42a94b5dd358f33c70ddeb3417f = L.map(
#                 &quot;map_6605e42a94b5dd358f33c70ddeb3417f&quot;,
#                 {
#                     center: [-6.214, 106.8235],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fa0b67ed46f19e44efb32bcf2edc853 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4fa0b67ed46f19e44efb32bcf2edc853.addTo(map_6605e42a94b5dd358f33c70ddeb3417f);
#
#
#             var poly_line_418340f348edd77653b4367df7218938 = L.polyline(
#                 [[-6.214, 106.8235], [-6.2133, 106.825], [-6.225, 106.8305], [-6.2145, 106.834], [-6.212, 106.799], [-6.2195, 106.8255], [-6.2235, 106.811], [-6.2275, 106.803], [-6.2305, 106.8015], [-6.2333, 106.7999], [-6.2325, 106.7995], [-6.2215, 106.8215], [-6.22, 106.8165], [-6.228, 106.81], [-6.214, 106.8305], [-6.2185, 106.8345], [-6.2185, 106.8365], [-6.224, 106.835], [-6.2295, 106.8165], [-6.2215, 106.8095], [-6.213, 106.838], [-6.2265, 106.845], [-6.2405, 106.815], [-6.2305, 106.8085], [-6.2305, 106.812], [-6.222, 106.8155]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF0000&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF0000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_6605e42a94b5dd358f33c70ddeb3417f);
#
#
#             poly_line_418340f348edd77653b4367df7218938.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_79e865d66bfc61c8f82bc709c3e952b3 = L.marker(
#                 [-6.214, 106.8235],
#                 {}
#             ).addTo(map_6605e42a94b5dd358f33c70ddeb3417f);
#
#
#             var beautify_icon_9d0964c9396d03454d3936ee0f7c39b3 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FF0000&quot;, &quot;borderColor&quot;: &quot;#FF0000&quot;, &quot;borderWidth&quot;: 2, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 23, &quot;textColor&quot;: &quot;white&quot;}
#             )
#             marker_79e865d66bfc61c8f82bc709c3e952b3.setIcon(beautify_icon_9d0964c9396d03454d3936ee0f7c39b3);
#
#
#             marker_79e865d66bfc61c8f82bc709c3e952b3.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 1&lt;br&gt;&lt;br&gt;Sequence number: 1&lt;br&gt;Order ID: 23&lt;br&gt;Location type: PICKUP&lt;br&gt;Weight: 8.12 kg&lt;br&gt;&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Pickup time:&lt;/span&gt;08:30:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Arrival time:&lt;/span&gt;08:40:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Delivery deadline:&lt;/span&gt;16:30:00&lt;br&gt;&lt;br&gt;Accumulated Distance: 0.00 km&lt;br&gt;Accumulated Weight: 8.12 kg&lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_de5d19dd42fbf419cc01d1d5d4105a9f = L.marker(
#                 [-6.2133, 106.825],
#                 {}
#             ).addTo(map_6605e42a94b5dd358f33c70ddeb3417f);
#
#
#             var beautify_icon_855bdb406b6689bebea3983b23958176 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FF0000&quot;, &quot;borderColor&quot;: &quot;#FF0000&quot;, &quot;borderWidth&quot;: 2, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 4, &quot;textColor&quot;: &quot;white&quot;}
#             )
#             marker_de5d19dd42fbf419cc01d1d5d4105a9f.setIcon(beautify_icon_855bdb406b6689bebea3983b23958176);

# %% [markdown]
# ## Map - 1~4 Hours

# %%
bm_2.add_single_route_to_map(batch_id=2, number_version=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70bcc222e3f9a2f6da63e98d75c19890 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70bcc222e3f9a2f6da63e98d75c19890&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70bcc222e3f9a2f6da63e98d75c19890 = L.map(
#                 &quot;map_70bcc222e3f9a2f6da63e98d75c19890&quot;,
#                 {
#                     center: [-7.2575, 112.7521],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10136e89d7732eb55d1612343dbc9212 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_10136e89d7732eb55d1612343dbc9212.addTo(map_70bcc222e3f9a2f6da63e98d75c19890);
#
#
#             var poly_line_48c52061f265328b741ee3d9fd2479de = L.polyline(
#                 [[-7.2575, 112.7521], [-7.2588, 112.7523], [-7.2708, 112.7449], [-7.2653, 112.7368], [-7.2706, 112.7392], [-7.2625, 112.7562], [-7.2717, 112.7568], [-7.2592, 112.7431], [-7.2679, 112.7362], [-7.2606, 112.7563]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF1493&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF1493&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_70bcc222e3f9a2f6da63e98d75c19890);
#
#
#             poly_line_48c52061f265328b741ee3d9fd2479de.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e9cb12a988e4a5ee2fab49472c0fa19f = L.marker(
#                 [-7.2575, 112.7521],
#                 {}
#             ).addTo(map_70bcc222e3f9a2f6da63e98d75c19890);
#
#
#             var beautify_icon_a0ddfe0095e5c87a9bca14bcc20bba1e = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FF1493&quot;, &quot;borderColor&quot;: &quot;#FF1493&quot;, &quot;borderWidth&quot;: 2, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 1, &quot;textColor&quot;: &quot;white&quot;}
#             )
#             marker_e9cb12a988e4a5ee2fab49472c0fa19f.setIcon(beautify_icon_a0ddfe0095e5c87a9bca14bcc20bba1e);
#
#
#             marker_e9cb12a988e4a5ee2fab49472c0fa19f.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 2&lt;br&gt;&lt;br&gt;Sequence number: 1&lt;br&gt;Order ID: 1&lt;br&gt;Location type: PICKUP&lt;br&gt;Weight: 7.54 kg&lt;br&gt;&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Pickup time:&lt;/span&gt;08:00:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Arrival time:&lt;/span&gt;08:10:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Delivery deadline:&lt;/span&gt;09:00:00&lt;br&gt;&lt;br&gt;Accumulated Distance: 0.00 km&lt;br&gt;Accumulated Weight: 7.54 kg&lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b9b2af51b183862139f6ca3322f1755e = L.marker(
#                 [-7.2588, 112.7523],
#                 {}
#             ).addTo(map_70bcc222e3f9a2f6da63e98d75c19890);
#
#
#             var beautify_icon_f981dffbe7225e38e25910aaf217d1ba = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FF1493&quot;, &quot;borderColor&quot;: &quot;#FF1493&quot;, &quot;borderWidth&quot;: 2, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 28, &quot;textColor&quot;: &quot;white&quot;}
#             )
#             marker_b9b2af51b183862139f6ca3322f1755e.setIcon(beautify_icon_f981dffbe7225e38e25910aaf217d1ba);
#
#
#             marker_b9b2af51b183862139f6ca3322f1755e.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 2&lt;br&gt;&lt;br&gt;Sequence number: 2&lt;br&gt;Order ID: 28&lt;br&gt;Location type: PICKUP&lt;br&gt;Weight: 9.23 kg&lt;br&gt;&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&

# %% [markdown]
# ## Map - Mixed

# %%
bm_3.add_single_route_to_map(batch_id=2, number_version=True)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa7fbf52dbbb441a41fef9ff3762ad65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa7fbf52dbbb441a41fef9ff3762ad65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa7fbf52dbbb441a41fef9ff3762ad65 = L.map(
#                 &quot;map_aa7fbf52dbbb441a41fef9ff3762ad65&quot;,
#                 {
#                     center: [-6.222, 106.8435],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72f604fdc072d0dce4542a447feac5e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_72f604fdc072d0dce4542a447feac5e0.addTo(map_aa7fbf52dbbb441a41fef9ff3762ad65);
#
#
#             var poly_line_96cda771d4ea8bb239d1eb5dd886f56c = L.polyline(
#                 [[-6.222, 106.8435], [-6.216, 106.8405], [-6.2144, 106.84], [-6.2145, 106.8425], [-6.2115, 106.844], [-6.2255, 106.811], [-6.228, 106.808], [-6.2255, 106.8045], [-6.2215, 106.8095], [-6.2175, 106.8115]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#FF1493&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#FF1493&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 0.8, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_aa7fbf52dbbb441a41fef9ff3762ad65);
#
#
#             poly_line_96cda771d4ea8bb239d1eb5dd886f56c.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 2
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b9c4eaae9231b558ff9c3ef2aa0a6ddd = L.marker(
#                 [-6.222, 106.8435],
#                 {}
#             ).addTo(map_aa7fbf52dbbb441a41fef9ff3762ad65);
#
#
#             var beautify_icon_54225805af33a3081afe9a3aaef2f4dc = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FF1493&quot;, &quot;borderColor&quot;: &quot;#FF1493&quot;, &quot;borderWidth&quot;: 2, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 84, &quot;textColor&quot;: &quot;white&quot;}
#             )
#             marker_b9c4eaae9231b558ff9c3ef2aa0a6ddd.setIcon(beautify_icon_54225805af33a3081afe9a3aaef2f4dc);
#
#
#             marker_b9c4eaae9231b558ff9c3ef2aa0a6ddd.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 2&lt;br&gt;&lt;br&gt;Sequence number: 1&lt;br&gt;Order ID: 84&lt;br&gt;Location type: PICKUP&lt;br&gt;Weight: 2.68 kg&lt;br&gt;&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Pickup time:&lt;/span&gt;08:25:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Arrival time:&lt;/span&gt;08:35:00&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;Delivery deadline:&lt;/span&gt;16:25:00&lt;br&gt;&lt;br&gt;Accumulated Distance: 0.00 km&lt;br&gt;Accumulated Weight: 2.68 kg&lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec00e4ce6bddfa4b6b6660ccbb89ee6c = L.marker(
#                 [-6.216, 106.8405],
#                 {}
#             ).addTo(map_aa7fbf52dbbb441a41fef9ff3762ad65);
#
#
#             var beautify_icon_9214f2d6fe8a813add01d13846046810 = new L.BeautifyIcon.icon(
#                 {&quot;backgroundColor&quot;: &quot;#FF1493&quot;, &quot;borderColor&quot;: &quot;#FF1493&quot;, &quot;borderWidth&quot;: 2, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconShape&quot;: &quot;circle&quot;, &quot;innerIconStyle&quot;: &quot;&quot;, &quot;isAlphaNumericIcon&quot;: true, &quot;spin&quot;: false, &quot;text&quot;: 72, &quot;textColor&quot;: &quot;white&quot;}
#             )
#             marker_ec00e4ce6bddfa4b6b6660ccbb89ee6c.setIcon(beautify_icon_9214f2d6fe8a813add01d13846046810);
#
#
#             marker_ec00e4ce6bddfa4b6b6660ccbb89ee6c.bindTooltip(
#                 `&lt;div&gt;
#                      Batch ID: 2&lt;br&gt;&lt;br&gt;Sequence number: 2&lt;br&gt;Order ID: 72&lt;br&gt;Location type: PICKUP&lt;br&gt;Weight: 3.45 kg&lt;br&gt;&lt;br&gt;&lt;span style=&#x27;display:inline-block; width:95px;&#x27;&gt;

# %% [markdown]
# # Table

# %% [markdown]
# ## Table - 8 Hours

# %%
bm_1.get_batch_metrics_table(batch_no=1)
# Out:
#     ID     Type   Weight   Arrival  Deadline (Created)  Acc Dist Acc Weight
# 0   23   PICKUP  8.12 kg  08:40:00  16:30:00  08:30:00   0.00 km    8.12 kg
# 1    4   PICKUP   8.7 kg  08:48:01  16:35:00  08:35:00   0.42 km   16.82 kg
# 2   40   PICKUP  3.52 kg  09:01:17  16:10:00  08:10:00   2.43 km   20.34 kg
# 3   12   PICKUP  8.57 kg  09:12:31  16:00:00  08:00:00   4.77 km   28.91 kg
# 4   12  DROPOFF           09:35:45  16:00:00  08:00:00  12.55 km   20.34 kg
# 5   28   PICKUP  9.23 kg  09:58:39  16:35:00  08:35:00  19.10 km   29.57 kg
# 6   40  DROPOFF           10:15:37  16:10:00  08:10:00  22.37 km   26.05 kg
# 7   15   PICKUP  2.17 kg  10:24:21  16:15:00  08:15:00  23.66 km   28.22 kg
# 8   28  DROPOFF           10:30:43  16:35:00  08:35:00  24.18 km   18.99 kg
# 9    4  DROPOFF           10:38:27  16:35:00  08:35:00  25.13 km   10.29 kg
# 10  23  DROPOFF           10:44:55  16:30:00  08:30:00  25.52 km    2.17 kg
# 11  47   PICKUP  8.89 kg  11:03:08  16:30:00  08:30:00  31.41 km   11.06 kg
# 12  35   PICKUP  2.85 kg  11:14:33  16:25:00  08:25:00  33.28 km   13.91 kg
# 13  35  DROPOFF           11:28:43  16:25:00  08:25:00  35.91 km   11.06 kg
# 14  15  DROPOFF           11:47:16  16:15:00  08:15:00  41.88 km    8.89 kg
# 15  81   PICKUP   5.0 kg  11:56:39  16:20:00  08:20:00  43.50 km   13.89 kg
# 16  99   PICKUP  2.71 kg  12:05:57  16:15:00  08:15:00  44.35 km   16.60 kg
# 17  62   PICKUP   2.7 kg  12:15:14  16:20:00  08:20:00  45.17 km   19.30 kg
# 18  81  DROPOFF           12:32:28  16:20:00  08:20:00  49.78 km   14.30 kg
# 19  99  DROPOFF           12:47:03  16:15:00  08:15:00  53.64 km   11.59 kg
# 20  56   PICKUP  4.55 kg  13:06:20  16:05:00  08:05:00  59.69 km   16.14 kg
# 21  67   PICKUP  0.94 kg  13:22:24  16:10:00  08:10:00  62.59 km   17.08 kg
# 22  47  DROPOFF           13:40:53  16:30:00  08:30:00  67.59 km    8.19 kg
# 23  67  DROPOFF           13:54:26  16:10:00  08:10:00  70.09 km    7.25 kg
# 24  56  DROPOFF           14:01:41  16:05:00  08:05:00  70.54 km    2.70 kg
# 25  62  DROPOFF           14:16:47  16:20:00  08:20:00  74.50 km    0.00 kg

# %% [markdown]
# ## Table - 1~4 Hours

# %%
bm_2.get_batch_metrics_table(batch_no=2)
# Out:
#    ID     Type   Weight   Arrival  Deadline (Created)  Acc Dist Acc Weight
# 0   1   PICKUP  7.54 kg  08:10:00  09:00:00  08:00:00   0.00 km    7.54 kg
# 1  28   PICKUP  9.23 kg  08:17:10  09:05:00  08:05:00   0.33 km   16.77 kg
# 2  28  DROPOFF           08:30:10  09:05:00  08:05:00   2.50 km    7.54 kg
# 3   1  DROPOFF           08:43:57  09:00:00  08:00:00   5.06 km    0.00 kg
# 4  25   PICKUP  3.29 kg  08:59:58  09:15:00  08:15:00   7.52 km    3.29 kg
# 5  25  DROPOFF           09:14:44  09:15:00  08:15:00  11.00 km    0.00 kg
# 6  31   PICKUP  3.86 kg  09:23:16  10:00:00  08:00:00  11.99 km    3.86 kg
# 7  31  DROPOFF           09:35:40  10:00:00  08:00:00  15.07 km    0.00 kg
# 8  37   PICKUP  3.25 kg  09:46:59  10:25:00  08:25:00  18.11 km    3.25 kg
# 9  37  DROPOFF           10:00:25  10:25:00  08:25:00  22.04 km    0.00 kg

# %% [markdown]
# ## Table - Mixed

# %%
bm_3.get_batch_metrics_table(batch_no=2)
# Out:
#    ID     Type   Weight   Arrival  Deadline (Created)  Acc Dist Acc Weight
# 0  84   PICKUP  2.68 kg  08:35:00  16:25:00  08:25:00   0.00 km    2.68 kg
# 1  72   PICKUP  3.45 kg  08:45:59  16:30:00  08:30:00   1.10 km    6.13 kg
# 2  61   PICKUP  4.82 kg  08:52:52  16:00:00  08:00:00   1.39 km   10.95 kg
# 3  96   PICKUP   1.8 kg  08:59:12  16:30:00  08:30:00   1.66 km   12.75 kg
# 4  64   PICKUP  6.11 kg  09:05:49  16:15:00  08:15:00   2.03 km   18.86 kg
# 5  72  DROPOFF           09:24:34  16:30:00  08:30:00   8.23 km   15.41 kg
# 6  84  DROPOFF           09:33:11  16:25:00  08:25:00   9.42 km   12.73 kg
# 7  64  DROPOFF           09:41:04  16:15:00  08:15:00  10.31 km    6.62 kg
# 8  61  DROPOFF           09:50:43  16:00:00  08:00:00  12.36 km    1.80 kg
# 9  96  DROPOFF           10:01:27  16:30:00  08:30:00  14.48 km    0.00 kg

# %% [markdown]
# # Stats

# %%
bm_1.optimize_stats()
# Out:
# Number of batch : 7
#
# Total distance   : 122.94 km
# Average distance : 17.56 km
# Maximum distance : 74.50 km
# Minimum distance : 6.05 km
#
#
# Total duration   : 08:18:09
# Average duration : 01:11:09
# Maximum duration : 05:36:47
# Minimum duration : 00:21:46

# %%
bm_2.optimize_stats()
# Out:
# Number of batch : 11
#
# Total distance   : 131.50 km
# Average distance : 11.95 km
# Maximum distance : 22.04 km
# Minimum distance : 4.88 km
#
#
# Total duration   : 08:33:25
# Average duration : 00:46:40
# Maximum duration : 01:50:25
# Minimum duration : 00:17:19

# %%
bm_3.optimize_stats()
# Out:
# Number of batch : 9
#
# Total distance   : 107.46 km
# Average distance : 11.94 km
# Maximum distance : 29.79 km
# Minimum distance : 6.50 km
#
#
# Total duration   : 07:29:38
# Average duration : 00:49:57
# Maximum duration : 02:11:09
# Minimum duration : 00:22:49
